# %% [markdown]
# # 0. Importação das Bibliotecas
# Antes de qualquer coisa é preciso importar os pacotes necessários para fazer a análise, o principal deles é o Pandas

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import color_sequences

# %% [markdown]
# # 1. Exploração e Visualização de Dados
# Aqui, importaremos um o arquivo .csv para um Dataframe do Pandas, e faremos a primeira análise de dados, verificando as informações disponíveis no arquivo

# %% [markdown]
# ## 1.1 Visualizando o Dataframe

# %%
df = pd.read_csv('data/pokemon.csv') # Importa o arquivo para um dataframe
df # Visualiza o dataframe
# Out:
#               Name             Type              Species  Height  Weight  \
# 0        Bulbasaur     Grass Poison         Seed Pokémon     0.7     6.9
# 1          Ivysaur     Grass Poison         Seed Pokémon     1.0    13.0
# 2         Venusaur     Grass Poison         Seed Pokémon     2.4   155.5
# 3       Charmander             Fire       Lizard Pokémon     0.6     8.5
# 4       Charmeleon             Fire        Flame Pokémon     1.1    19.0
# ...            ...              ...                  ...     ...     ...
# 1009   Raging Bolt  Electric Dragon      Paradox Pokémon     5.2   480.0
# 1010  Iron Boulder     Rock Psychic      Paradox Pokémon     1.5   162.5
# 1011    Iron Crown    Steel Psychic      Paradox Pokémon     1.6   156.0
# 1012     Terapagos           Normal         Tera Pokémon     1.7    77.0
# 1013     Pecharunt     Poison Ghost  Subjugation Pokémon     0.3     0.3
#
#                                     Abilities  Catch rate  Base Friendship  \
# ...

# %% [markdown]
# ## 1.2 Informações Gerais
# Utilizando o método *info()*, é possível ter uma visão mais detalhada do nosso dataframe, com o total de linhas e colunas e também os tipos de dados de cada coluna

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1014 entries, 0 to 1013
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             1014 non-null   object
#  1   Type             1014 non-null   object
#  2   Species          1014 non-null   object
#  3   Height           1014 non-null   float64
#  4   Weight           1014 non-null   float64
#  5   Abilities        1014 non-null   object
#  6   Catch rate       1014 non-null   int64
#  7   Base Friendship  1014 non-null   int64
#  8   Base Exp.        1014 non-null   int64
#  9   Growth Rate      1014 non-null   object
#  10  Gender           1014 non-null   object
#  11  HP               1014 non-null   int64
#  12  Attack           1014 non-null   int64
#  13  Defense          1014 non-null   int64
#  14  Sp. Atk          1014 non-null   int64
#  15  Sp. Def          1014 non-null   int64
#  16  Speed            1014 non-null   int64
# ...

# %% [markdown]
# ## 1.3 Valores Nulos
# Para garantir que não há valores nulos no dataframe, há várias formas de verificar os valores nulos, a função *isna()* retorna um dataframe com valores booleanos mostrando se é nulo ou não, com isso em mente, é possível usar a função *sum()* para retornar um dataframe que mostrará o total de valores nulos em cada coluna

# %%
df.isna().sum() # É possível usar essa função para linhas, utilizando o parametro sum(axis = 1)
# Out:
# Name               0
# Type               0
# Species            0
# Height             0
# Weight             0
# Abilities          0
# Catch rate         0
# Base Friendship    0
# Base Exp.          0
# Growth Rate        0
# Gender             0
# HP                 0
# Attack             0
# Defense            0
# Sp. Atk            0
# Sp. Def            0
# Speed              0
# dtype: int64

# %% [markdown]
# # 2. Análise Qualitativa
# "Dados qualitativos são informações que descrevem **qualidades ou categorias** em vez de valores numéricos. Eles são usados para classificar ou rotular elementos em um conjunto de dados"

# %% [markdown]
# ## 2.1 Contagem de tipos de Pokémon
# Vamos contar quantos Pokémons únicos existem na base de dados, e quais são os diferentes tipos de Pokémon, e quantos existem de cada tipo.

# %%
df['Name'].nunique() # A função Nunique retorna o total de elementos unicos encontrados na coluna
# Out:
# 1014

# %%
df['Type'].value_counts() # Essa função retorna o total de ocorrencias em uma coluna do dataframe
# Out:
# Type
# Water              73
# Normal             64
# Grass              43
# Psychic            40
# Electric           31
#                    ..
# Dragon Dark         1
# Fairy Fighting      1
# Fighting Dragon     1
# Grass Rock          1
# Poison Ghost        1
# Name: count, Length: 214, dtype: int64

# %% [markdown]
# ## 2.2 Habilidades Únicas
# Agora vamos repetir o que fizemos para os tipos de Pokémon, utilizando a função *value_counts()* para contar o total de habilidades únicas e também verificar a habilidade mais comum entre os Pokémon utilizando *idmax()* na series retornada, ou seja, o valor que mais se repete nessa coluna.

# %%
df['Abilities'].nunique() # Aqui, repete-se o processo de verificar o total de valores unicos em uma coluna
# Out:
# 652

# %%
df['Abilities'].value_counts().idxmax() # Retorna o nome do elemento que mais se repete na coluna
# Out:
# '1. Levitate'

# %% [markdown]
# ## 2.3 Taxa de captura
# Aqui, aplicaremos outras funções para verificar a taxa de captura mais comum, e qual o Pokémon com a maior taxa de captura, e qual tem a menor taxa de captura, utilizando filtragem, é possível notar que há mais de um Pokémon que se encaixa nesses critérios

# %%
df['Catch rate'].mode() # Por se tratar de numeros inteiros, utilizamos apenas a moda matematica (numero mais frequente) para descobrir qual a taxa de captura mais comum
# Out:
# 0    45
# Name: Catch rate, dtype: int64

# %% [markdown]
# ### Filtrando Pokémons baseado na taxa de captura

# %%
greatest_cr = df['Catch rate'] == df['Catch rate'].max() # Filtro de maior taxa de captura
lowest_cr = df['Catch rate'] == df['Catch rate'].min()

# %%
# Aqui sera impressa a lista apenas de Pokemons que tem a menor taxa de captura
df[lowest_cr]
# Out:
#              Name             Type              Species  Height  Weight  \
# 137      Articuno   Psychic Flying        Cruel Pokémon     1.7    50.9
# 138        Zapdos  Fighting Flying  Strong Legs Pokémon     1.6    58.2
# 139       Moltres      Dark Flying   Malevolent Pokémon     2.0    66.0
# 143        Mewtwo          Psychic      Genetic Pokémon     1.5    33.0
# 236        Raikou         Electric      Thunder Pokémon     1.9   178.0
# ...           ...              ...                  ...     ...     ...
# 996      Miraidon  Electric Dragon      Paradox Pokémon     3.5   240.0
# 1002      Okidogi  Poison Fighting     Retainer Pokémon     1.8    92.0
# 1003    Munkidori   Poison Psychic     Retainer Pokémon     1.0    12.2
# 1004  Fezandipiti     Poison Fairy     Retainer Pokémon     1.4    30.1
# 1013    Pecharunt     Poison Ghost  Subjugation Pokémon     0.3     0.3
#
#                                       Abilities  Catch rate  Base Friendship  \
# ...

# %%
# Aqui sera impressa a lista de Pokemons com a maior taxa de captura
df[greatest_cr]
# Out:
#             Name           Type              Species  Height  Weight  \
# 9       Caterpie            Bug         Worm Pokémon     0.3     2.9
# 12        Weedle     Bug Poison    Hairy Bug Pokémon     0.3     3.2
# 15        Pidgey  Normal Flying    Tiny Bird Pokémon     0.3     1.8
# 18       Rattata    Dark Normal        Mouse Pokémon     0.3     3.8
# 20       Spearow  Normal Flying    Tiny Bird Pokémon     0.3     2.0
# ...          ...            ...                  ...     ...     ...
# 905   Tarountula            Bug  String Ball Pokémon     0.3     4.0
# 916       Smoliv   Grass Normal        Olive Pokémon     0.3     6.5
# 920        Nacli           Rock    Rock Salt Pokémon     0.4    16.0
# 948      Wiglett          Water   Garden Eel Pokémon     1.2     1.8
# 1012   Terapagos         Normal         Tera Pokémon     1.7    77.0
#
#                                               Abilities  Catch rate  \
# 9               1. Shield DustRun Away (hidden ability)         255
# ...

# %% [markdown]
# # 3. Análise Quantitativa
# "Quando analisamos uma variável qualitativa, basicamente construímos uma **distribuição de frequência**. No entanto, ao explorarmos variáveis quantitativas, temos condições de empregar algumas medidas descritivas que sintetizam as características da distribuição"

# %% [markdown]
# ## 3.1 Características Físicas dos Pokémons
# Para ter uma análise quantitativa mais dinâmica, vamos separar dados entre características físicas e estatísticas de batalha. Primeiro vamos analisar a altura e o peso dos Pokémons, e analisar se há alguma relação entre altura e peso

# %%
weight_mean = df['Weight'].mean() # Calculando a media de peso ddf['Body Type'] = os Pokemons
height_mean = df['Height'].mean()
print('O peso médio é:', weight_mean)
print('A altura média é:', height_mean)
# Out:
# O peso médio é: 71.73224852071006
# A altura média é: 1.3567061143984218

# %% [markdown]
# ### Relacionando Altura e Peso
# É possível criar uma correlação entre peso utilizando a fórmula do IMC (Peso/Altura^2)

# %%
df['IMC'] = df['Weight']/(df['Height'] ** 2)
df.head(5)
# Out:
#          Name          Type         Species  Height  Weight  \
# 0   Bulbasaur  Grass Poison    Seed Pokémon     0.7     6.9
# 1     Ivysaur  Grass Poison    Seed Pokémon     1.0    13.0
# 2    Venusaur  Grass Poison    Seed Pokémon     2.4   155.5
# 3  Charmander          Fire  Lizard Pokémon     0.6     8.5
# 4  Charmeleon          Fire   Flame Pokémon     1.1    19.0
#
#                                  Abilities  Catch rate  Base Friendship  \
# 0  1. OvergrowChlorophyll (hidden ability)          45               50
# 1  1. OvergrowChlorophyll (hidden ability)          45               50
# 2                                Thick Fat          45               50
# 3     1. BlazeSolar Power (hidden ability)          45               50
# 4     1. BlazeSolar Power (hidden ability)          45               50
#
#    Base Exp.  Growth Rate                    Gender  HP  Attack  Defense  \
# 0         64  Medium Slow  87.5% male, 12.5% female  45      49       49
# ...

# %% [markdown]
# ## 3.2 Estatísticas de Batalha
# Agora, as estatísticas de batalha serão analisadas, calcularemos o maior valor total de estatísticas (*soma de hp, ataque, defesa, etc.*), Os Pokémons mais rápidos e a variação de HP entre os diferentes tipos de Pokémon

# %%
# Criando uma coluna que soma todas as estatisticas de batalha de um Pokémon
df['Overall Power'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Def'] + df['Sp. Atk'] + df['Speed']

# Criando um filtro para descobrir os que se encaixam nos criterios dados
greatest_power = df['Overall Power'] == df['Overall Power'].max()
df[greatest_power]
# Out:
#           Name           Type           Species  Height  Weight Abilities  \
# 878  Eternatus  Poison Dragon  Gigantic Pokémon   100.0   950.0  Pressure
#
#      Catch rate  Base Friendship  Base Exp. Growth Rate      Gender   HP  \
# 878         255                0        563        Slow  Genderless  255
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed    IMC  Overall Power
# 878     115      250      125      250    130  0.095           1125

# %%
# Organizando os valores pela velocidade de forma descendente e mostrando apenas os 5 primeiros elementos do dataframe
df.sort_values('Speed', ascending = False).head(5)
# Out:
#           Name           Type            Species  Height  Weight  \
# 882  Regieleki       Electric   Electron Pokémon     1.2   145.0
# 379     Deoxys        Psychic        DNA Pokémon     1.7    60.8
# 284    Ninjask     Bug Flying      Ninja Pokémon     0.8    12.0
# 785  Pheromosa   Bug Fighting    Lissome Pokémon     1.8    25.0
# 886    Calyrex  Psychic Ghost  High King Pokémon     2.4    53.6
#
#                                       Abilities  Catch rate  Base Friendship  \
# 882                               1. Transistor           3               35
# 379                                    Pressure           3                0
# 284  1. Speed BoostInfiltrator (hidden ability)         120               50
# 785                              1. Beast Boost          45                0
# 886                                      As One           3              100
#
#      Base Exp. Growth Rate                Gender   HP  Attack  Defense  \
# ...

# %% [markdown]
# ### Análise da média de HP
# Utilizando o método *groupby()*, vamos criar verificar a média de HP para cada tipo de Pokémon

# %%
df.groupby('Type')['HP'].mean()
# Out:
# Type
# Bug              49.000000
# Bug Dark         71.000000
# Bug Electric     63.500000
# Bug Fairy        50.000000
# Bug Fighting     85.750000
#                    ...
# Water Ice        90.000000
# Water Poison     60.000000
# Water Psychic    72.666667
# Water Rock       79.500000
# Water Steel      84.000000
# Name: HP, Length: 214, dtype: float64

# %% [markdown]
# # 4. Demonstrando Estatísticas
# Os dados serão filtrados, e gráficos serão criados para demonstrar algumas estatísticas sobre os Pokémon

# %% [markdown]
# ##  4.1 Filtragem de dados
# Vamos criar filtros para os Pokémon do tipo "Fire" e para os Pokémon com ataque acima de 100

# %%
fire_type = df['Type'] == 'Fire'
atk_greater_100 = df['Attack'] > 100

# Aplica ambos os filtros e mostra apenas os Pokémon do tipo fogo com ataque acima de 100
df[fire_type & atk_greater_100]
# Out:
#           Name  Type          Species  Height  Weight  \
# 129    Flareon  Fire    Flame Pokémon     0.9    25.0
# 237      Entei  Fire  Volcano Pokémon     2.1   198.0
# 805  Cinderace  Fire  Striker Pokémon     1.4    33.0
#
#                                    Abilities  Catch rate  Base Friendship  \
# 129       1. Flash FireGuts (hidden ability)          45               50
# 237  1. PressureInner Focus (hidden ability)           3               35
# 805          1. BlazeLibero (hidden ability)          45               50
#
#      Base Exp.  Growth Rate                    Gender   HP  Attack  Defense  \
# 129        184  Medium Fast  87.5% male, 12.5% female   65     130       60
# 237        261         Slow                Genderless  115     115       85
# 805        265  Medium Slow  87.5% male, 12.5% female   80     116       75
#
#      Sp. Atk  Sp. Def  Speed        IMC  Overall Power
# 129       95      110     65  30.864198            525
# ...

# %% [markdown]
# ## 4.2 Criação de Gráficos
# Serão feitos 2 gráficos, um gráfico de barras para a quantidade de Pokémon por tipo e um gráfico de dispersão monstrando a relação de Ataque e Defesa

# %% [markdown]
# ### Gráfico de Tipo de Pokémon

# %%
df['Type'] = df['Type'].apply(lambda x: ' '.join(sorted(x.split(' '))))

# %%
type_counts = df['Type'].value_counts()
colors = ['blue','red','green']

plt.figure(figsize=(25, 6)) # Define o tamanho da figura (imagem do grafico)
type_counts.plot(kind='bar') # Cria o grafico de barra
plt.title('Quantidade de Pokémon por Tipo') # Titulo
plt.xlabel('Tipo de Pokémon') # Rotulo do eixo x
plt.ylabel('Quantidade') # Rotulo do eixo y
plt.xticks(rotation=90,ha='center',fontsize=7) # Deixa os nomes dos tipos mais legiveis

plt.show()

# %% [markdown]
# ### Gráfico de Dispersão de Pokémon

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['Attack'], df['Defense'], alpha=0.5, c='blue') # Cria um grafico de dispersao que recebe os valores das colunas attack e defense como parametros
plt.title('Relação Ataque / Defesa')
plt.xlabel('Ataque')
plt.ylabel('Defesa')
plt.grid(True)
plt.show()

# %%
df.groupby('Type')['HP'].value_counts()
# Out:
# Type   HP
# Bug    50     6
#        45     3
#        65     2
#        25     1
#        33     1
#              ..
# Water  90     1
#        95     1
#        150    1
#        165    1
#        170    1
# Name: count, Length: 786, dtype: int64
